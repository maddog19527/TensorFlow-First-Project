# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn import preprocessing
from datetime import datetime
from Preprocessingfunctions import convertclock,OutlierDetection
import statsmodels.api as spearman
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler

shotlogs=pd.read_csv('shot_logs.csv')

# %%
X=shotlogs[['FINAL_MARGIN','SHOT_NUMBER','PERIOD','GAME_CLOCK','SHOT_CLOCK','DRIBBLES','TOUCH_TIME','SHOT_DIST','PTS_TYPE','CLOSE_DEF_DIST','LOCATION','W','SHOT_RESULT']]
pearson=X.corr(method='pearson')
spearman=X.corr(method='spearman')

# %% [markdown]
# Pearson and Spearman Analysis

# %%
plt.figure(figsize=(10,8))
sns.heatmap(pearson, annot=True, cmap='coolwarm')
plt.title('Pearson Correlation Matrix')
plt.show()

plt.figure(figsize=(10,8))
sns.heatmap(spearman, annot=True, cmap='coolwarm')
plt.title('Spearman Correlation Matrix')
plt.show()

# %% [markdown]
# Using VIF to determine collinearity

# %%
vif_data=pd.DataFrame()
vif_data['features']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#           features        VIF
# 0     FINAL_MARGIN   2.805431
# 1      SHOT_NUMBER   5.629557
# 2           PERIOD  10.212300
# 3       GAME_CLOCK   3.918553
# 4       SHOT_CLOCK   1.128657
# 5         DRIBBLES   8.162263
# 6       TOUCH_TIME  10.879884
# 7        SHOT_DIST   7.100560
# 8         PTS_TYPE  20.799765
# 9   CLOSE_DEF_DIST   4.572266
# 10               W   5.565413
# 11     SHOT_RESULT   1.895004
# 12        LOCATION   2.009911
